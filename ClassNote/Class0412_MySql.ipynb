# %% [markdown]
# 참조사이트
# https://www.mysqltutorial.org/
#
#
# 1. My SQL 삭제
#
# 2. mysql.com 접속 (또는 오라클 접속)
#
# 3. my sql community server
#
# 4. my sql installer
# Windows (x86, 32-bit), MSI Installer
#
# ![image.png](attachment:image.png)
#
#
# 5. install
# ![image-2.png](attachment:image-2.png)
#
# Port: 3306
#
# ![image-3.png](attachment:image-3.png)
# password: 1234
#
# ![image-4.png](attachment:image-4.png)
#
#
# 6. mySQL Workbench
#
# 생성 >>> schemas >>>
#
# - 데이타베이스 만들기 (schema만들기)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# CREATE SCHEMA `pywebdb` DEFAULT CHARACTER SET utf8 ; >>> sql 스크립트(언어)
#
# workbench에 스키마 만들어짐.
#
#
# 7. 테이블 만들기
# ![image-8.png](attachment:image-8.png)
# ![image-9.png](attachment:image-9.png)
# ![image-10.png](attachment:image-10.png)
# ![image-11.png](attachment:image-11.png)       >>> 명령어 실행 (한줄실행, 여러줄 샐행)
# ![image-12.png](attachment:image-12.png)
#
# tbl.....으로 이름생성
# ![image-13.png](attachment:image-13.png)
#
# PK: primary key
# NN: Non nul >>> primary key에서는 반드시 생성
# ![image-14.png](attachment:image-14.png)
# UQ: uniq
#
# VARCHAR(45) >>> var을 붙여주면, 실제 데이타에 맞게 자리를 주고, 나머지 자리는 돌려줌. 한글 한글자는 3바이트. 45바이트 확보
#
# <!-- -------테이블 생성하기-------------
# CREATE TABLE `pywebdb`.`tblbookmark` (
#   `id` INT NOT NULL AUTO_INCREMENT,
#   `site` VARCHAR(100) NOT NULL,
#   `url` VARCHAR(300) NOT NULL,
#   PRIMARY KEY (`id`),
#   UNIQUE INDEX `site_UNIQUE` (`site` ASC) VISIBLE)
# ENGINE = InnoDB
# DEFAULT CHARACTER SET = utf8;
# --------------------------------------------- -->
#
# ![image-15.png](attachment:image-15.png)
#
# 8. 데이타 생성
