# %% [markdown]
# progrming 언어 : 초급반 수업
# Syntax
# OOP (객체지향)
# Python Qt : GUI (DB base)
# Stand alone application (DB 연결 GUI: 공개되지 않음.) : 이번 과정에서는 생략.
# TCP/IP 프로토콜에서 HTTP(전송규약)기반의 application :
# Web Frame work (HTTP에서 application을 만들수 있도록) : 파이썬에서 사용할 수 있는 도구 >>> Django, Flask >>> 나의 PC가 서버역할을 하게 된다. *** 인스타그램: 파이썬으로 만들어짐.
# https://www.djangoproject.com/ 다운로드: 최신버전 다운은 권하지 않음. 옵션2로 다운로드 권장 (pip install django)
#
# documentation 페이지에서 'ko'를 선택 >>> 한글페이지로 이동 https://docs.djangoproject.com/ko/3.1/intro/install/
#
# 가상환경?
#
# python console에서 장고 설치 확인
#
# https://docs.djangoproject.com/ko/3.1/
#
# [최종결과물: part1 ~ part7] Palls (설문지) 앱을 만든다.
#
# 모델: 데이타베이스 관리자페이지: Framework이기 때문에 관리자 페이지가 기본제공
#
# 구글번역기 사용: 웹스토어에서 구글번역기 다운받아 우측상단에 고정시킴.
#
#
# ![image.png](attachment:image.png)
#
#
# My site폴더 생성
#
# manage.py:커맨드라인의 유틸리티 mysite/settings.py: 현재 Django 프로젝트의 환경 및 구성을 저장합니다. Django settings에서 환경 설정이 어떻게 동작하는지 확인할 수 있습니다. mysite/urls.py: 현재 Django project 의 URL 선언을 저장합니다. Django 로 작성된 사이트의 《목차》 라고 할 수 있습니다. URL dispatcher 에서 URL 에 대한 자세한 내용을 읽어보세요.
#
# 서버동작확인: python manage.py runserver Starting development server at http://127.0.0.1:8000/
#
# python console에서 ctrl + c >>> 서버가 닫힌다.
#
# polls 앱 생성 sqllite3가 기본생성 : 파이썬의 기본데이타베이스
#
#
# ![image.png](attachment:image.png)
#
#
# 최상위 URLconf (My site)에서
#
#
#
# ![image-2.png](attachment:image-2.png)
#
#
# ![image-3.png](attachment:image-3.png)
#
#
# : 다른 데이타베이스 설정
#
# (venv) C:\Github\django\mysite>python manage.py migrate
#
#
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)
#
#
# ![image-3.png](attachment:image-3.png)
#
#
# sql의 migration실행
#
# migration이란: DB안에 테이블을 만드는 것. API는 자동으로 생성되어 있음.
#
# CRUD: 자료 생성/조회/수정/삭제
#
# manage.py 파일은 util 과 같은 역할을 한다.
