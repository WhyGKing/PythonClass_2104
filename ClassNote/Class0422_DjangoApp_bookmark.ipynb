# %% [markdown]
# 결과물 창
# http://swcodingschool.pythonanywhere.com/bookmark/
#
# * HTML에서 {{ }}는 단지 출력만 한다.
#
#
# * base.html
# - Head부분
# <!--
#     {% load static %}  <!-- static 요소를 로드하겠다.-->
#     <link rel="stylesheet" href="{% static 'style.css' %}">
#     <script src="{% static 'bootstrap.bundle.min.js' %}"></script> -->
# ===> 사용자 지정을 static을 통해서 불러온다.
#
# https://getbootstrap.com/
# ===> bootstrap 다운로드 후 static폴더에 관련파일 복사
#
#
# 'DIRS': [os.path.join(BASE_DIR, 'templates')],
# BASE_DIR : 해당프로젝트를 의미함.
#
#
#
# STATIC_URL = '/static/'
#
#
#
# {% block content %}
# {% endblock %}
#
#
#
# {% extends 'base.html' %}
# {% block title%} List {% endblock %}
# {% block content %}
#
#
#
#
# #### 서버에 올리기
#
# - settings.file
# DEBUG = False
#
# ALLOWED_HOSTS = ['*']     # .pythonanywhere.com
#
#
# 1) FTP로 올리기
#
#
# 2) Git에 올려서 복사해서 올리기
#
#
# https://www.pythonanywhere.com/
#
# https://www.pythonanywhere.com/pricing/
#
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# $ ls -la >>>>자주 쓰는 명령어
#
# ##### Pythonanywhere.com의 console을 이용해서 서버에 로그인한 상태(리눅스 시스템)
# 1. git을 이용해 프로젝트 파일을 다운로드
#   git clone https://github.com/WhyGKing/djangoboomark.git
#
# 2. 프로젝트 이름으로 이동
# cd djangobookmark
#
# 3. 가상환경만들기
# $ virtualenv venv --python=python3.7
#
# 4. 가상환경 활성화
# $ source venv/bin/activate
#
# 5. 가상환경에 장고설치
# $ pip install django
#
# 6. 마이그레이트 작업을 진행하고
# $ python manage.py migrate
#
#
# ....
#
# 9. WSGI configuration file 편집
# https://www.pythonanywhere.com/user/WhyGKing/webapps/#tab_id_whygking_pythonanywhere_com
#
# >> WSGI configuration file:/var/www/whygking_pythonanywhere_com_wsgi.py
