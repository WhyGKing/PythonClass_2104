# %% [markdown]
# pythonanywhere.com 접속
# /djangobookmark/config 파일로 이동
#
# vi settings.py 실행
#
# ESC 후에 J 아래로 이동 (K: 위로 이동, L: 오른쪽으로 이동, H: 왼쪽으로 이동)
# Name에서 str ' '으로 묶어준다.
#
# shift + 콜론 >>> 프로그램 빠져나오면 명령어 줄로...
# wq! >>>> write and quit
#
#
# 콘솔이 달라져서 django를 재실행해야함. 가상환경으로 이동 후
# ![image-2.png](attachment:image-2.png)
#
# 콘솔에서 exit하면 console이 사라짐. bash에 다시 들어감.
# ![image-3.png](attachment:image-3.png)
#
# $ deactivate  >>> 가상환경에서 빠져나옴.
#
# rm -rf venv >>>> venv파일 삭제 (-rf 아래포함 파일 삭제, 묻지말고)
#
# 10:39 ~/djangoboomark (master)$ virtualenv venv
#
# ![image-4.png](attachment:image-4.png)
#
# 가상환경 재설정하고, django재설치했지만, 계속 에러발생
# ![image-4.png](attachment:image-4.png)
#
#
# migration을 재설정하기 위해서...
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png) >>>데이타베이스 완전히 삭제
#
# ![image-8.png](attachment:image-8.png) >>>계속 에러남.
#
#
#
# ### 친구정보관리 게시판
#
#
# 파이참>>>새프로젝트
# (venv) C:\Github\friends>django-admin startproject config .
